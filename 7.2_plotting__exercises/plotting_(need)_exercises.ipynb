# %% [markdown]
# <div style="text-align:left;font-size:2em"><span style="font-weight:bolder;font-size:1.25em">SP2273 | Learning Portfolio</span><br><br><span style="font-weight:bold;color:darkred">Plotting (Need) Exercises</span></div>

# %% [markdown]
# Installing necessary stuff...

# %%
conda install matplotlib -c conda-forge
# Out:
# 2 channel Terms of Service accepted
# Channels:
#  - conda-forge
#  - defaults
# Platform: osx-arm64
# Collecting package metadata (repodata.json): done
# Solving environment: done
#
# # All requested packages already installed.
#
#
# Note: you may need to restart the kernel to use updated packages.

# %%
from matplotlib import pyplot as plt

# %% [markdown]
# #### Exercise 1

# %%
# Some data for plotting
x = [0, 1, 2, 3, 4, 5]
y = [0, 4, 8, 12, 16, 20]
y_err = [0.0, 0.5, 1.0, 1.5, 2.0, 2.5]
x_err = .25

plt.errorbar(x, y, 
             xerr=x_err, yerr=y_err,
             color='red', linestyle='dashed',
             marker='*', markerfacecolor='yellow',
             #? am I supposed to guess the marker styles???
             ## I searched google for the types of styles..
             # marker = symbol indicating data points
             # markerfacecolor = color of marker *point*
             ecolor='black',capsize=5,
             # ecolor = "marker" line color
             label='Y values with errors')
             # adding "label=" after defining "marker" will produce a
             # name for the markers, which can be shown using plt.legend
plt.xlabel('x-values')
plt.ylabel('y-values')
plt.title('X vs Y')
plt.grid(alpha=.25)
plt.legend(loc='lower right') # shows legend for anything 
                              # that has been labelled in this graph?
plt.show()

# %% [markdown]
# #### Exercise 2

# %%
import numpy as np
import math

# %%
x = np.array(list(range(0, 50)))
x = np.linspace(0, 50, 300)
                                ## which one do i use?? 
                                ## they seem to be the same...
                                # np.linspace(start, stop, num)
                                # where num = number of evenly spaced 
                                # values to be generated

y = np.exp(-x/10)*np.sin(x) # should i use np.linsoace for y too?

plt.plot(x, y, color  ='blue')

plt.ylim(-1, 1)
plt.grid(alpha = 0.25)
plt.xlabel('X values', fontsize = 15, color = 'darkorange')
plt.ylabel('Y values', fontsize = 15, color = 'darkorange')
plt.title(r'$Y = e^{-\frac{x}{10}}\sin(x)$', fontsize=20)
plt.legend(loc='lower right')
# Out:
# /var/folders/18/rms181n50dvbpnff1c8lq0xm0000gn/T/ipykernel_83243/935164562.py:18: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend(loc='lower right')
